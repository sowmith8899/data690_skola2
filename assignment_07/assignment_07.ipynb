# %% [markdown]
# <a href="https://colab.research.google.com/github/sowmith8899/data690_skola2/blob/main/assignment_07/assignment_07.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment - 07

# %% [markdown]
# - Use this link to load the data https://raw.githubusercontent.com/wcj365/python-stats-dataviz/master/assignments/assignment_07_world_dev/world_devlopment_indicator.csv

# %%
import pandas as pd
import plotly.express as px

# %%
url = "https://raw.githubusercontent.com/wcj365/python-stats-dataviz/master/assignments/assignment_07_world_dev/world_devlopment_indicator.csv"
df = pd.read_csv(url)
df
# Out:
#        Unnamed: 0  Year         value          indicator Country Code  \
# 0               0  2002  8.763276e+02  NY.GDP.PCAP.PP.CD          AFG
# 1               1  2003  9.281916e+02  NY.GDP.PCAP.PP.CD          AFG
# 2               2  2004  9.257042e+02  NY.GDP.PCAP.PP.CD          AFG
# 3               3  2005  1.023550e+03  NY.GDP.PCAP.PP.CD          AFG
# 4               4  2006  1.078907e+03  NY.GDP.PCAP.PP.CD          AFG
# ...           ...   ...           ...                ...          ...
# 34949       34949  2017  1.423660e+07        SP.POP.TOTL          ZWE
# 34950       34950  2018  1.443881e+07        SP.POP.TOTL          ZWE
# 34951       34951  2019  1.464547e+07        SP.POP.TOTL          ZWE
# 34952       34952  2020  1.486293e+07        SP.POP.TOTL          ZWE
# 34953       34953  2021  1.509217e+07        SP.POP.TOTL          ZWE
#
#       Country Name               Region         Income Group Lending Type
# ...

# %% [markdown]
# - You must pick one indicator out of the four: population, life expectancy, GDP per capita, or suiside rate
# - You must pick a few countries of your interest and compare them to see how they differ in the indicator
#  - Compare one year (pick the latest year) using bar chart, pie chart, and boxplot
#  - Compare all years using line chart

# %%
df['indicator'].value_counts()
# Out:
# SP.POP.TOTL          13411
# SP.DYN.LE00.IN       11930
# NY.GDP.PCAP.PP.CD     5953
# SH.STA.SUIC.P5        3660
# Name: indicator, dtype: int64

# %%
df['Country Name'].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Angola',
#        'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba',
#        'Australia', 'Austria', 'Azerbaijan', 'Bahamas, The', 'Bahrain',
#        'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin',
#        'Bermuda', 'Bhutan', 'Bolivia', 'Bosnia and Herzegovina',
#        'Botswana', 'Brazil', 'Brunei Darussalam', 'Bulgaria',
#        'Burkina Faso', 'Burundi', 'Cabo Verde', 'Cambodia', 'Cameroon',
#        'Canada', 'Cayman Islands', 'Central African Republic', 'Chad',
#        'Chile', 'China', 'Colombia', 'Comoros', 'Congo, Dem. Rep.',
#        'Congo, Rep.', 'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Curacao',
#        'Cyprus', 'Czechia', 'Denmark', 'Djibouti', 'Dominica',
#        'Dominican Republic', 'Ecuador', 'Egypt, Arab Rep.', 'El Salvador',
#        'Equatorial Guinea', 'Eritrea', 'Estonia', 'Eswatini', 'Ethiopia',
#        'Fiji', 'Finland', 'France', 'Gabon', 'Gambia, The', 'Georgia',
# ...

# %%
df[['Country Code','Country Name']].sample(8)
# Out:
#       Country Code           Country Name
# 23176          BRA                 Brazil
# 26145          GHA                  Ghana
# 26552          GTM              Guatemala
# 23606          KHM               Cambodia
# 34625          VNM                Vietnam
# 28562          LBY                  Libya
# 21317          VIR  Virgin Islands (U.S.)
# 2780           KEN                  Kenya

# %% [markdown]
# **Defination of Indicators :**
# - **NY.GDP.PCAP.PP.CD** -- GDP per capita, PPP (current international $)
# - **SP.DYN.LE00.IN** -- Life expectancy at birth, total (years)
# - **SH.STA.SUIC.P5** -- Suicide mortality rate (per 100,000 population)
# - **SP.POP.TOTL** -- Population, total
#
# *Ref : https://www.worlddev.xyz/*

# %% [markdown]
# Filtering data as per requirement

# %% [markdown]
# #### Selecting below countries for Visualisation :
# Netherlands
# India
# Nicaragua
# Peru
# Nauru
# Indonesia
# Trinidad and Tobago
# Costa Rica

# %%
df1 = df.loc[df["Country Code"].isin(["NLD","IND","NIC","PER","NRU","IDN","TTO","CRI"])]
df1
# Out:
#        Unnamed: 0  Year         value          indicator Country Code  \
# 1298         1298  1990  5.023829e+03  NY.GDP.PCAP.PP.CD          CRI
# 1299         1299  1991  5.174305e+03  NY.GDP.PCAP.PP.CD          CRI
# 1300         1300  1992  5.630680e+03  NY.GDP.PCAP.PP.CD          CRI
# 1301         1301  1993  6.016225e+03  NY.GDP.PCAP.PP.CD          CRI
# 1302         1302  1994  6.261706e+03  NY.GDP.PCAP.PP.CD          CRI
# ...           ...   ...           ...                ...          ...
# 33739       33739  2017  1.384060e+06        SP.POP.TOTL          TTO
# 33740       33740  2018  1.389841e+06        SP.POP.TOTL          TTO
# 33741       33741  2019  1.394969e+06        SP.POP.TOTL          TTO
# 33742       33742  2020  1.399491e+06        SP.POP.TOTL          TTO
# 33743       33743  2021  1.403374e+06        SP.POP.TOTL          TTO
#
#               Country Name                      Region         Income Group  \
# ...

# %% [markdown]
# Selecting GDP as indicator for 2021

# %%
gdp1 = df1.query('indicator == "NY.GDP.PCAP.PP.CD" and Year == 2021')
gdp1
# Out:
#       Unnamed: 0  Year         value          indicator Country Code  \
# 1329        1329  2021  23387.132225  NY.GDP.PCAP.PP.CD          CRI
# 2451        2451  2021   7333.505612  NY.GDP.PCAP.PP.CD          IND
# 2483        2483  2021  12904.335065  NY.GDP.PCAP.PP.CD          IDN
# 3764        3764  2021  15102.661039  NY.GDP.PCAP.PP.CD          NRU
# 3828        3828  2021  63766.887113  NY.GDP.PCAP.PP.CD          NLD
# 3892        3892  2021   6331.672499  NY.GDP.PCAP.PP.CD          NIC
# 4232        4232  2021  13895.275816  NY.GDP.PCAP.PP.CD          PER
# 5390        5390  2021  26868.092719  NY.GDP.PCAP.PP.CD          TTO
#
#              Country Name                      Region         Income Group  \
# 1329           Costa Rica  Latin America & Caribbean   Upper middle income
# 2451                India                  South Asia  Lower middle income
# 2483            Indonesia         East Asia & Pacific  Lower middle income
# ...

# %%
fig = px.bar(gdp1, x='Country Name', y='value',color='Country Name',title='GDP rate of selected 8 countires for 2021 using bar')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.pie(gdp1, names='Country Name', values='value',color='Country Name',title='GDP rate of selected 8 countires for 2021 using pie')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.box(gdp1, x='Country Name', y='value',color='Country Name',title='GDP rate of selected 8 countires for 2021 using pie')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
gdp2 = df1.query('indicator == "NY.GDP.PCAP.PP.CD"')
gdp2
# Out:
#       Unnamed: 0  Year         value          indicator Country Code  \
# 1298        1298  1990   5023.828755  NY.GDP.PCAP.PP.CD          CRI
# 1299        1299  1991   5174.305356  NY.GDP.PCAP.PP.CD          CRI
# 1300        1300  1992   5630.679652  NY.GDP.PCAP.PP.CD          CRI
# 1301        1301  1993   6016.224583  NY.GDP.PCAP.PP.CD          CRI
# 1302        1302  1994   6261.705701  NY.GDP.PCAP.PP.CD          CRI
# ...          ...   ...           ...                ...          ...
# 5386        5386  2017  27277.878321  NY.GDP.PCAP.PP.CD          TTO
# 5387        5387  2018  27616.894200  NY.GDP.PCAP.PP.CD          TTO
# 5388        5388  2019  27959.529076  NY.GDP.PCAP.PP.CD          TTO
# 5389        5389  2020  26125.153291  NY.GDP.PCAP.PP.CD          TTO
# 5390        5390  2021  26868.092719  NY.GDP.PCAP.PP.CD          TTO
#
#              Country Name                      Region         Income Group  \
# ...

# %%
fig = px.line(gdp2, x='Year', y='value',color='Country Name',title='GDP rate of selected 8 countires for all years using line')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df2 = df1.query('Year == 2021')
df3 = df2.groupby(['Country Name']).mean()
print(df3)
# Out:
#                      Unnamed: 0    Year         value
# Country Name
# Costa Rica              12892.5  2021.0  2.581220e+06
# India                   14781.5  2021.0  6.967082e+08
# Indonesia               14828.5  2021.0  1.381873e+08
# Nauru                   16924.5  2021.0  1.298783e+04
# Netherlands             17018.5  2021.0  8.798586e+06
# Nicaragua               17143.5  2021.0  3.354355e+06
# Peru                    17685.5  2021.0  1.668666e+07
# Trinidad and Tobago     19566.5  2021.0  7.151210e+05

# %%
con = df1['Country Name'].unique().tolist()
df3['Country Name'] = con
df3
# Out:
#                      Unnamed: 0    Year         value         Country Name
# Country Name
# Costa Rica              12892.5  2021.0  2.581220e+06           Costa Rica
# India                   14781.5  2021.0  6.967082e+08                India
# Indonesia               14828.5  2021.0  1.381873e+08            Indonesia
# Nauru                   16924.5  2021.0  1.298783e+04                Nauru
# Netherlands             17018.5  2021.0  8.798586e+06          Netherlands
# Nicaragua               17143.5  2021.0  3.354355e+06            Nicaragua
# Peru                    17685.5  2021.0  1.668666e+07                 Peru
# Trinidad and Tobago     19566.5  2021.0  7.151210e+05  Trinidad and Tobago

# %%
fig = px.bar(df3, x='Country Name', y='value',color='Country Name',title='GDP rate of selected 8 countires for 2021 using bar')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.pie(df3, names='Country Name', values='value',color='Country Name',title='GDP rate of selected 8 countires for 2021 using pie')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.box(df2, x='Country Name', y='value',color='Country Name',title='GDP rate of selected 8 countires for 2021 using pie')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df4 = df1.groupby(['Region']).mean()
print(df4)
# Out:
#                               Unnamed: 0         Year         value
# Region
# East Asia & Pacific         18570.313725  1995.305882  4.404984e+07
# Europe & Central Asia       18380.645714  1995.240000  5.285345e+06
# Latin America & Caribbean   18159.000000  1995.240000  2.695011e+06
# South Asia                  15974.074286  1995.240000  3.177644e+08

# %%
fig = px.bar(gdp1, x='Region', y='value',color='Country Name',title='GDP rate of all regions for 2021 using bar')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.pie(gdp1, names='Region', values='value',color='Country Name',title='GDP rate of all regions for 2021 using pie')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.line(gdp2, x='Year', y='value',color='Region',title='GDP rate of all regions for all years using line')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df5 = pd.pivot_table(df, values = 'value', index=['Country Code', 'Country Name','Region','Year'], columns = 'indicator').reset_index()
df5.dropna(inplace=True)
df5
# Out:
# indicator Country Code Country Name               Region  Year  \
# 104                AFG  Afghanistan           South Asia  2002
# 105                AFG  Afghanistan           South Asia  2003
# 106                AFG  Afghanistan           South Asia  2004
# 107                AFG  Afghanistan           South Asia  2005
# 108                AFG  Afghanistan           South Asia  2006
# ...                ...          ...                  ...   ...
# 13416              ZWE     Zimbabwe  Sub-Saharan Africa   2015
# 13417              ZWE     Zimbabwe  Sub-Saharan Africa   2016
# 13418              ZWE     Zimbabwe  Sub-Saharan Africa   2017
# 13419              ZWE     Zimbabwe  Sub-Saharan Africa   2018
# 13420              ZWE     Zimbabwe  Sub-Saharan Africa   2019
#
# indicator  NY.GDP.PCAP.PP.CD  SH.STA.SUIC.P5  SP.DYN.LE00.IN  SP.POP.TOTL
# 104               876.327643             5.0          56.784   22600774.0
# ...

# %%
grp = df5[['Region', 'NY.GDP.PCAP.PP.CD','SH.STA.SUIC.P5','SP.DYN.LE00.IN','SP.POP.TOTL']]

# %%
grp.groupby(['Region']).mean().plot(figsize = (20,9),title = 'Comparision b/w Regions and Indicators')

# %%
df6 = pd.pivot_table(df, values = 'value', index=['Country Code', 'Country Name','Region','Year'], columns = 'indicator').reset_index()
df6 = df5.query('Year == 2020')
fig = px.scatter(df6,x="NY.GDP.PCAP.PP.CD",y="SP.DYN.LE00.IN",color="Country Name", title="Wealth vs Health",)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
