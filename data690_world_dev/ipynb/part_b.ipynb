# %% [markdown]
# <a href="https://colab.research.google.com/github/sowmith8899/data690_skola2/blob/main/data690_world_dev/ipynb/part_b.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Individual Project Part B
#
# For this part, you are a data scientist and will use Jupyter Notebook to recreate the charts you used in Part A using Plotly Express. You can copy and paste the texts from your Part A into your Jupyter Notebook and format them so that your Notebook will be a self-contained well-documented project.
#
# Source : https://www.worlddev.xyz/

# %% [markdown]
# ## Theme : Education
#
# ### Topics used for analysis :
# ```
# Education
# Social Development
# Gender
# ```
#
# ### Abstract:
#
# - In this analysis, The primary topics used is Education and to analyse the data we used few indicators from Social development and Gender.
# - Education means studying in order to obtain a deeper knowledge and understanding of a variety of subjects to be applied to daily life. Education is not limited to just knowledge from books, but can also be obtained through practical experiences outside of the classroom.
# - In order for the entire world to really become equal, it needs to start with education. If everyone was provided with the same opportunities to education, then there would be less gaps between social classes.
# - More than 260 million children worldwide are out of school, yet more than half of those in education are not learning, the "World Bank has warned".
# - In today’s society, having an education is considered a vital part of being accepted by those around you. Having an education is believed to make you a useful part of society, and can make you feel like a contributing member as well.
#
# ### Global education facts:
#
# - In 39 out of 99 countries, fewer than 50% of the poorest children have completed primary school. In some countries like South Sudan, that figure is as low as 7%.
# - More than 50% of young people in 58 out of 133 countries have not completed upper secondary school. In Niger, only 2% of its young people have completed this education.
# - In 35 out of 75 countries, at least 25% of the poorest young women are illiterate.
# - In 30 countries, fewer than 90 females for every 100 males complete lower-secondary school.
#
# ## Indicators used :
# ```
# - Population ages 15-64(% of total population).
# - Literacy rate, youth total(% of people ages 15-24).
# - Government expenditure on education, total(% of government expenditure).
# - Unemployment, total(% of total labor force).
# - School enrollment, primary and secondary (gross), gender parity index (GPI)
# - Employment to population ratio, ages 15-24, female (%) (modeled ILO estimate)
# - Employment to population ratio, ages 15-24, male (%) (modeled ILO estimate)
# ```
# **Countries:**
# ```
# - India
# - Pakistan
# - China
# - Nepal
# - Germany
# - Bangladesh
# - Australia
# - Afganistan
# - Malaysia
# - United States
# ```
#
# **Time Plot Years:**
# - 2016 - 2021.

# %% [markdown]
# Notes for Part A : https://github.com/sowmith8899/data690_skola2/blob/main/data690_world_dev/wdx_analysis.md

# %% [markdown]
# *Importing the required Libraries*

# %%
import pandas as pd
import plotly
import plotly.express as px

# %% [markdown]
# Reading the data set from source

# %%
df = pd.read_csv("https://raw.githubusercontent.com/sowmith8899/data690_skola2/main/data690_world_dev/part_b690_data.csv")
df
# Out:
#      Unnamed: 0  Year      value          indicator Country Code Country Name  \
# 0             0  2016  13.091000  SE.XPD.TOTL.GB.ZS          AFG  Afghanistan
# 1             1  2017  12.033200  SE.XPD.TOTL.GB.ZS          AFG  Afghanistan
# 2             2  2018  11.696060  SE.XPD.TOTL.GB.ZS          AFG  Afghanistan
# 3             3  2019  11.343770  SE.XPD.TOTL.GB.ZS          AFG  Afghanistan
# 4             4  2020  10.253860  SE.XPD.TOTL.GB.ZS          AFG  Afghanistan
# ..          ...   ...        ...                ...          ...          ...
# 337         337  2019  96.778397  SE.ADT.1524.LT.ZS          MYS     Malaysia
# 338         338  2018  92.393806  SE.ADT.1524.LT.ZS          NPL        Nepal
# 339         339  2017  74.526382  SE.ADT.1524.LT.ZS          PAK     Pakistan
# 340         340  2018  71.994843  SE.ADT.1524.LT.ZS          PAK     Pakistan
# 341         341  2019  72.703560  SE.ADT.1524.LT.ZS          PAK     Pakistan
#
#                   Region         Income Group Lending Type
# 0             South Asia           Low income          IDA
# 1             South Asia           Low income          IDA
# 2             South Asia           Low income          IDA
# 3             South Asia           Low income          IDA
# 4             South Asia           Low income          IDA
# ..                   ...                  ...          ...
# 337  East Asia & Pacific  Upper middle income         IBRD
# 338           South Asia  Lower middle income          IDA
# 339           South Asia  Lower middle income        Blend
# 340           South Asia  Lower middle income        Blend
# 341           South Asia  Lower middle income        Blend
#
# [342 rows x 9 columns]

# %% [markdown]
# Checking the data

# %%
df['Country Name'].unique()
# Out:
# array(['Afghanistan', 'Australia', 'Bangladesh', 'China', 'Germany',
#        'India', 'Malaysia', 'Nepal', 'Pakistan', 'United States'],
#       dtype=object)

# %%
df['indicator'].unique()
# Out:
# array(['SE.XPD.TOTL.GB.ZS', 'SL.EMP.1524.SP.FE.ZS', 'SE.ENR.PRSC.FM.ZS',
#        'SP.POP.1564.TO.ZS', 'SL.EMP.1524.SP.MA.ZS', 'SL.UEM.TOTL.ZS',
#        'SE.ADT.1524.LT.ZS'], dtype=object)

# %% [markdown]
# Creating pivot table for our analysis

# %%
df_p = pd.pivot_table(df, values = 'value', index=['Country Code', 'Country Name','Year'], columns = 'indicator').reset_index()

df_p.head()
# Out:
# indicator Country Code Country Name  Year  SE.ADT.1524.LT.ZS  \
# 0                  AFG  Afghanistan  2016                NaN
# 1                  AFG  Afghanistan  2017                NaN
# 2                  AFG  Afghanistan  2018                NaN
# 3                  AFG  Afghanistan  2019                NaN
# 4                  AFG  Afghanistan  2020                NaN
#
# indicator  SE.ENR.PRSC.FM.ZS  SE.XPD.TOTL.GB.ZS  SL.EMP.1524.SP.FE.ZS  \
# 0                    0.64567           13.09100                14.572
# 1                    0.64169           12.03320                15.439
# 2                    0.63602           11.69606                15.766
# 3                        NaN           11.34377                16.059
# 4                        NaN           10.25386                12.640
#
# indicator  SL.EMP.1524.SP.MA.ZS  SL.UEM.TOTL.ZS  SP.POP.1564.TO.ZS
# 0                     49.255001          11.158          53.207964
# 1                     48.611000          11.180          53.763223
# 2                     48.443001          11.152          54.324898
# 3                     48.199001          11.217          54.911934
# 4                     43.655998          11.710          55.528329

# %% [markdown]
# **Population ages 15-64(% of total population):**

# %%
df1 = df.query("Year == 2016").query("indicator == 'SP.POP.1564.TO.ZS'")
df1.sample(5)
# Out:
#      Unnamed: 0  Year      value          indicator Country Code Country Name  \
# 176         176  2016  66.274262  SP.POP.1564.TO.ZS          IND        India
# 158         158  2016  66.111323  SP.POP.1564.TO.ZS          BGD   Bangladesh
# 182         182  2016  69.080619  SP.POP.1564.TO.ZS          MYS     Malaysia
# 188         188  2016  62.076944  SP.POP.1564.TO.ZS          NPL        Nepal
# 152         152  2016  65.906573  SP.POP.1564.TO.ZS          AUS    Australia
#
#                   Region         Income Group    Lending Type
# 176           South Asia  Lower middle income            IBRD
# 158           South Asia  Lower middle income             IDA
# 182  East Asia & Pacific  Upper middle income            IBRD
# 188           South Asia  Lower middle income             IDA
# 152  East Asia & Pacific          High income  Not classified

# %%
fig = px.bar(
   df1, 
    x="Country Name", 
    labels={"value":"2016 Bar Plot of all countries Population Ages", "Country Name":""},
    y="value",
    color="Country Name",
    )


fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="f3906198-1491-4aed-8e09-c3016e7783c0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f3906198-1491-4aed-8e09-c3016e7783c0")) {                    Plotly.newPlot(                        "f3906198-1491-4aed-8e09-c3016e7783c0",                        [{"alignmentgroup":"True","hovertemplate":"=%{x}<br>2016 Bar Plot of all countries Population Ages=%{y}<extra></extra>","legendgroup":"Afghanistan","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Afghanistan","offsetgroup":"Afghanistan","orientation":"v","showlegend":true,"textposition":"auto","x":["Afghanistan"],"xaxis":"x","y":[53.2079642016],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"=%{x}<br>2016 Bar Plot of all countries Population Ages=%{y}<extra></extra>","legendgroup":"Australia","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Australia","offsetgroup":"Australia","orientation":"v","showlegend":true,"textposition":"auto","x":["Australia"],"xaxis":"x","y":[65.9065730162],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"=%{x}<br>2016 Bar Plot of all countries Population Ages=%{y}<extra></extra>","legendgroup":"Bangladesh","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Bangladesh","offsetgroup":"Bangladesh","orientation":"v","showlegend":true,"textposition":"auto","x":["Bangladesh"],"xaxis":"x","y":[66.1113230721],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"=%{x}<br>2016 Bar Plot of all countries Population Ages=%{y}<extra></extra>","legendgroup":"China","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"China","offsetgroup":"China","orientation":"v","showlegend":true,"textposition":"auto","x":["China"],"xaxis":"x","y":[72.2027527737],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"=%{x}<br>2016 Bar Plot of all countries Population Ages=%{y}<extra></extra>","legendgroup":"Germany","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Germany","offsetgroup":"Germany","orientation":"v","showlegend":true,"textposition":"auto","x":["Germany"],"xaxis":"x","y":[65.3959908493],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"=%{x}<br>2016 Bar Plot of all countries Population Ages=%{y}<extra></extra>","legendgroup":"India","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"India","offsetgroup":"India","orientation":"v","showlegend":true,"textposition":"auto","x":["India"],"xaxis":"x","y":[66.2742624653],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"=%{x}<br>2016 Bar Plot of all countries Population Ages=%{y}<extra></extra>","legendgroup":"Malaysia","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Malaysia","offsetgroup":"Malaysia","orientation":"v","showlegend":true,"textposition":"auto","x":["Malaysia"],"xaxis":"x","y":[69.0806192568],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"=%{x}<br>2016 Bar Plot of all countries Population Ages=%{y}<extra></extra>","legendgroup":"Nepal","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Nepal","offsetgroup":"Nepal","orientation":"v","showlegend":true,"textposition":"auto","x":["Nepal"],"xaxis":"x","y":[62.0769438684],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"=%{x}<br>2016 Bar Plot of all countries Population Ages=%{y}<extra></extra>","legendgroup":"Pakistan","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"Pakistan","offsetgroup":"Pakistan","orientation":"v","showlegend":true,"textposition":"auto","x":["Pakistan"],"xaxis":"x","y":[59.986273823],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"=%{x}<br>2016 Bar Plot of all countries Population Ages=%{y}<extra></extra>","le ...

# %%
fig = px.choropleth(df1, 
                    locations='Country Name',
                    locationmode="country names", 
                    color='value',
                    template="plotly_dark",
                    title = "2016 Population ages 15-64(% of total population)"
                    )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="bdeed09e-bde5-47e7-b0b1-4e90497ae685" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bdeed09e-bde5-47e7-b0b1-4e90497ae685")) {                    Plotly.newPlot(                        "bdeed09e-bde5-47e7-b0b1-4e90497ae685",                        [{"coloraxis":"coloraxis","geo":"geo","hovertemplate":"Country Name=%{location}<br>value=%{z}<extra></extra>","locationmode":"country names","locations":["Afghanistan","Australia","Bangladesh","China","Germany","India","Malaysia","Nepal","Pakistan","United States"],"name":"","z":[53.2079642016,65.9065730162,66.1113230721,72.2027527737,65.3959908493,66.2742624653,69.0806192568,62.0769438684,59.986273823,65.942978768],"type":"choropleth"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie" ...

# %% [markdown]
# * In the above given graph, we could observe that China being a highly populated country stands in the first position with almost 72% of educated population from age 15 to 64. Followed bt Malaysia with 69 % of second highest educated crowd. Although, Afghanistan places in the last with about 53% it is quiet impressable being a small country.

# %% [markdown]
# **Literacy rate, youth total(% of people ages 15-24):**

# %%
fig = px.line(
    df.query("indicator == 'SE.ADT.1524.LT.ZS'"), 
    x="Year", 
    labels={"value":"Literacy Rate %"},
    y="value",
    color="Country Name",
    title="Literacy rate, youth total(% of people ages 15-24)."
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="d8c19d20-c14e-40c9-9464-791df6693542" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d8c19d20-c14e-40c9-9464-791df6693542")) {                    Plotly.newPlot(                        "d8c19d20-c14e-40c9-9464-791df6693542",                        [{"hovertemplate":"Country Name=Afghanistan<br>Year=%{x}<br>Literacy Rate %=%{y}<extra></extra>","legendgroup":"Afghanistan","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Afghanistan","orientation":"v","showlegend":true,"x":[2021],"xaxis":"x","y":[55.9294013977],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country Name=Bangladesh<br>Year=%{x}<br>Literacy Rate %=%{y}<extra></extra>","legendgroup":"Bangladesh","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Bangladesh","orientation":"v","showlegend":true,"x":[2016,2017,2018,2019,2020],"xaxis":"x","y":[92.2426528931,92.9507598877,93.2964401245,94.8624267578,94.4617767334],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country Name=China<br>Year=%{x}<br>Literacy Rate %=%{y}<extra></extra>","legendgroup":"China","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"China","orientation":"v","showlegend":true,"x":[2018],"xaxis":"x","y":[99.7835998535],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country Name=India<br>Year=%{x}<br>Literacy Rate %=%{y}<extra></extra>","legendgroup":"India","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"India","orientation":"v","showlegend":true,"x":[2018],"xaxis":"x","y":[91.6640396118],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country Name=Malaysia<br>Year=%{x}<br>Literacy Rate %=%{y}<extra></extra>","legendgroup":"Malaysia","line":{"color":"#FFA15A","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Malaysia","orientation":"v","showlegend":true,"x":[2016,2017,2018,2019],"xaxis":"x","y":[97.6144714355,97.2725601196,96.8503265381,96.7783966064],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country Name=Nepal<br>Year=%{x}<br>Literacy Rate %=%{y}<extra></extra>","legendgroup":"Nepal","line":{"color":"#19d3f3","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Nepal","orientation":"v","showlegend":true,"x":[2018],"xaxis":"x","y":[92.3938064575],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country Name=Pakistan<br>Year=%{x}<br>Literacy Rate %=%{y}<extra></extra>","legendgroup":"Pakistan","line":{"color":"#FF6692","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Pakistan","orientation":"v","showlegend":true,"x":[2017,2018,2019],"xaxis":"x","y":[74.5263824463,71.9948425293,72.7035598755],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"], ...

# %% [markdown]
# * As we go through the above time series graph of the total youth literacy rate, Malaysia takes the highest position with an eventual growth of rate. The growth rate is quite interesting. Bangladesh falls second starting with 92% and ending at 94% starting in the year 2016 until 2021.Due to lack data for rest of the countries , we are unable to analys

# %% [markdown]
# **Government expenditure on education, total(% of government expenditure):**

# %%
df3  = df.query("Year == 2016").query("indicator == 'SE.XPD.TOTL.GB.ZS'")
df3.sample(5)
# Out:
#     Unnamed: 0  Year      value          indicator Country Code Country Name  \
# 39          39  2016  15.063480  SE.XPD.TOTL.GB.ZS          PAK     Pakistan
# 9            9  2016  11.419280  SE.XPD.TOTL.GB.ZS          BGD   Bangladesh
# 0            0  2016  13.091000  SE.XPD.TOTL.GB.ZS          AFG  Afghanistan
# 23          23  2016  15.721500  SE.XPD.TOTL.GB.ZS          IND        India
# 15          15  2016  11.885478  SE.XPD.TOTL.GB.ZS          CHN        China
#
#                  Region         Income Group Lending Type
# 39           South Asia  Lower middle income        Blend
# 9            South Asia  Lower middle income          IDA
# 0            South Asia           Low income          IDA
# 23           South Asia  Lower middle income         IBRD
# 15  East Asia & Pacific  Upper middle income         IBRD

# %%
fig = px.bar(
    df3, 
    x="Country Name", 
    y="value", 
    title="Government expenditure on education, total(% of government expenditure)", 
    labels={"value":"2016 Govt Expenditure", "Country Name":""},
    color="Country Name", 
    template="plotly_dark"
)


fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="4d199838-0ff9-406d-b1fe-39cf2a832600" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4d199838-0ff9-406d-b1fe-39cf2a832600")) {                    Plotly.newPlot(                        "4d199838-0ff9-406d-b1fe-39cf2a832600",                        [{"alignmentgroup":"True","hovertemplate":"=%{x}<br>2016 Govt Expenditure=%{y}<extra></extra>","legendgroup":"Afghanistan","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Afghanistan","offsetgroup":"Afghanistan","orientation":"v","showlegend":true,"textposition":"auto","x":["Afghanistan"],"xaxis":"x","y":[13.0909996033],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"=%{x}<br>2016 Govt Expenditure=%{y}<extra></extra>","legendgroup":"Australia","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Australia","offsetgroup":"Australia","orientation":"v","showlegend":true,"textposition":"auto","x":["Australia"],"xaxis":"x","y":[13.8043899536],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"=%{x}<br>2016 Govt Expenditure=%{y}<extra></extra>","legendgroup":"Bangladesh","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Bangladesh","offsetgroup":"Bangladesh","orientation":"v","showlegend":true,"textposition":"auto","x":["Bangladesh"],"xaxis":"x","y":[11.4192800522],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"=%{x}<br>2016 Govt Expenditure=%{y}<extra></extra>","legendgroup":"China","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"China","offsetgroup":"China","orientation":"v","showlegend":true,"textposition":"auto","x":["China"],"xaxis":"x","y":[11.8854780197],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"=%{x}<br>2016 Govt Expenditure=%{y}<extra></extra>","legendgroup":"Germany","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Germany","offsetgroup":"Germany","orientation":"v","showlegend":true,"textposition":"auto","x":["Germany"],"xaxis":"x","y":[10.9105396271],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"=%{x}<br>2016 Govt Expenditure=%{y}<extra></extra>","legendgroup":"India","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"India","offsetgroup":"India","orientation":"v","showlegend":true,"textposition":"auto","x":["India"],"xaxis":"x","y":[15.7215003967],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"=%{x}<br>2016 Govt Expenditure=%{y}<extra></extra>","legendgroup":"Malaysia","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Malaysia","offsetgroup":"Malaysia","orientation":"v","showlegend":true,"textposition":"auto","x":["Malaysia"],"xaxis":"x","y":[20.9357204437],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"=%{x}<br>2016 Govt Expenditure=%{y}<extra></extra>","legendgroup":"Nepal","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Nepal","offsetgroup":"Nepal","orientation":"v","showlegend":true,"textposition":"auto","x":["Nepal"],"xaxis":"x","y":[19.1284999847],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"=%{x}<br>2016 Govt Expenditure=%{y}<extra></extra>","legendgroup":"Pakistan","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"Pakistan","offsetgroup":"Pakistan","orientation":"v","showlegend":true,"textposition":"auto","x":["Pakistan"],"xaxis":"x","y":[15.0634803772],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"=%{x}<br>2016 Govt Expenditure=%{y}<extra></extra>","legendgroup":"United States","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"United States","offsetgroup":"United States","orientation":"v","showlegend":true,"textposition":"auto","x":["United States"],"xaxis":"x","y":[13.1542100906],"yaxi ...

# %% [markdown]
# * Analysing the above bar chart , Malaysia holds the top most position with 20 of amount spent by the government for education purposes. Second goes Nepal with 19%, followed by India, Pakisthan, Australia.

# %% [markdown]
# **Unemployment, total(% of total labor force)**

# %%
df4 = df.query("indicator == 'SL.UEM.TOTL.ZS'")
df4.sample(5)
# Out:
#      Unnamed: 0  Year   value       indicator Country Code Country Name  \
# 296         296  2016   5.423  SL.UEM.TOTL.ZS          IND        India
# 266         266  2016  11.158  SL.UEM.TOTL.ZS          AFG  Afghanistan
# 279         279  2017   4.370  SL.UEM.TOTL.ZS          BGD   Bangladesh
# 310         310  2018   3.193  SL.UEM.TOTL.ZS          NPL        Nepal
# 313         313  2021   5.052  SL.UEM.TOTL.ZS          NPL        Nepal
#
#          Region         Income Group Lending Type
# 296  South Asia  Lower middle income         IBRD
# 266  South Asia           Low income          IDA
# 279  South Asia  Lower middle income          IDA
# 310  South Asia  Lower middle income          IDA
# 313  South Asia  Lower middle income          IDA

# %%
fig = px.line(
    df4, 
    x="Year", 
    labels={"value":"Unemployement Rate %"},
    y="value",
    color="Country Name",
    title="Literacy rate, youth total(% of people ages 15-24)."
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="0f360b31-1b20-455a-a195-4357372c4553" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0f360b31-1b20-455a-a195-4357372c4553")) {                    Plotly.newPlot(                        "0f360b31-1b20-455a-a195-4357372c4553",                        [{"hovertemplate":"Country Name=Afghanistan<br>Year=%{x}<br>Unemployement Rate %=%{y}<extra></extra>","legendgroup":"Afghanistan","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Afghanistan","orientation":"v","showlegend":true,"x":[2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[11.1579999924,11.1800003052,11.1520004272,11.2170000076,11.7100000381,13.2829999924],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country Name=Australia<br>Year=%{x}<br>Unemployement Rate %=%{y}<extra></extra>","legendgroup":"Australia","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Australia","orientation":"v","showlegend":true,"x":[2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[5.7100000381000005,5.5900001526,5.3000001907,5.1599998474,6.4600000381000005,5.1119999886],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country Name=Bangladesh<br>Year=%{x}<br>Unemployement Rate %=%{y}<extra></extra>","legendgroup":"Bangladesh","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Bangladesh","orientation":"v","showlegend":true,"x":[2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[4.3499999046,4.3699998856,4.4130001068,4.4380002022,5.4130001068,5.2290000916],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country Name=China<br>Year=%{x}<br>Unemployement Rate %=%{y}<extra></extra>","legendgroup":"China","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"China","orientation":"v","showlegend":true,"x":[2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[4.5300002098,4.4400000572,4.2800002098,4.5199999809,5.0,4.8169999123],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country Name=Germany<br>Year=%{x}<br>Unemployement Rate %=%{y}<extra></extra>","legendgroup":"Germany","line":{"color":"#FFA15A","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Germany","orientation":"v","showlegend":true,"x":[2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[4.1199998856,3.75,3.3800001144,3.1400001049,3.8099999428,3.5350000858],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country Name=India<br>Year=%{x}<br>Unemployement Rate %=%{y}<extra></extra>","legendgroup":"India","line":{"color":"#19d3f3","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"India","orientation":"v","showlegend":true,"x":[2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[5.4229998589,5.3579998016,5.3299999237,5.2699999809,7.9970002174,5.978000164],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country Name=Malaysia<br>Year=%{x}<br>Unemployement Rate %=%{y}<extra></extra>","legendgroup":"Malaysia","line":{"color":"#FF6692","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Malaysia","orientation":"v","showlegend":true,"x":[2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[3.4400000572,3.4100000858,3.2999999523,3.2599999905,4.5040001869,4.609000206],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country Name=Nepal<br>Year=%{x}<br>Unemployement Rate %=%{y}<extra></extra>","legendgroup":"Nepal","line":{"color":"#B6E880","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Nepal","orientation":"v","showlegend":true,"x":[2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[2.8680000305,3.3180000782,3.1930000782,3.0969998837,4.7239999771,5.0520000458],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country Name=Pakistan<br>Year=%{x}<br>Unemployem ...

# %% [markdown]
# * In the above time series graph, we could easily notice various zig-zag observations varying from year to year. The graph explains us the total percentage of unemployment. The highest percentage is taken by Afganisthan starting from 11% to 13%.Until 2019, the graph was consistent. After 2019 the percentage has suddenly increased. We can see in 2020 almost in all countries the unemployement was at spike maybe this was due to covid but later we see in all countries the digits were same of previous to 2019 except Afghanisthan.

# %% [markdown]
# **Umemployment vs Total Population:**

# %%
fig = px.scatter(
    df_p.query('Year == 2016'),
    y="SL.UEM.TOTL.ZS",
    x="SP.POP.1564.TO.ZS", 
    trendline="lowess",
    text="Country Name",
    title="Umemployment vs Total Population", 

)

fig.update_traces(textposition="top right")

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="081686a8-5f50-49ec-a27e-ae14215532d5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("081686a8-5f50-49ec-a27e-ae14215532d5")) {                    Plotly.newPlot(                        "081686a8-5f50-49ec-a27e-ae14215532d5",                        [{"hovertemplate":"SP.POP.1564.TO.ZS=%{x}<br>SL.UEM.TOTL.ZS=%{y}<br>Country Name=%{text}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers+text","name":"","orientation":"v","showlegend":false,"text":["Afghanistan","Australia","Bangladesh","China","Germany","India","Malaysia","Nepal","Pakistan","United States"],"x":[53.2079642016,65.9065730162,66.1113230721,72.2027527737,65.3959908493,66.2742624653,69.0806192568,62.0769438684,59.986273823,65.942978768],"xaxis":"x","y":[11.1579999924,5.7100000381000005,4.3499999046,4.5300002098,4.1199998856,5.4229998589,3.4400000572,2.8680000305,3.7790000439,4.8699998856],"yaxis":"y","type":"scatter","textposition":"top right"},{"hovertemplate":"<b>LOWESS trendline</b><br><br>SP.POP.1564.TO.ZS=%{x}<br>SL.UEM.TOTL.ZS=%{y} <b>(trend)</b><extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"lines","name":"","showlegend":false,"x":[53.2079642016,59.986273823,62.0769438684,65.3959908493,65.9065730162,65.942978768,66.1113230721,66.2742624653,69.0806192568,72.2027527737],"xaxis":"x","y":[11.14890653096229,3.778971508899849,3.9154492687419693,4.10740476310593,4.858901551032343,4.91251435356514,5.1604715823752265,5.400692568179334,3.4407664598226186,4.5190847080509755],"yaxis":"y","type":"scatter","textposition":"top right"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0 ...

# %% [markdown]
# In the ploted scatter graph , Afghanistan has highest percentage of unemployment, which constitutes around 11% whereas we can see Nepal even though being smallest country with highly education percent of 62%. They still have a feeble unemployment rate of 2%. This whole data was only for the year of 2016 the same consistency has been noticed till 2021 as discussed above there was you fluctuations in year 2020.

# %% [markdown]
# **School Enrollments:**

# %%
df5 = df.query("indicator == 'SE.ENR.PRSC.FM.ZS'")
df5.sample(5)
# Out:
#      Unnamed: 0  Year    value          indicator Country Code Country Name  \
# 114         114  2018  1.11591  SE.ENR.PRSC.FM.ZS          BGD   Bangladesh
# 121         121  2016  0.96373  SE.ENR.PRSC.FM.ZS          DEU      Germany
# 132         132  2019  1.04038  SE.ENR.PRSC.FM.ZS          MYS     Malaysia
# 126         126  2017  1.08402  SE.ENR.PRSC.FM.ZS          IND        India
# 141         141  2019  0.87748  SE.ENR.PRSC.FM.ZS          PAK     Pakistan
#
#                     Region         Income Group    Lending Type
# 114             South Asia  Lower middle income             IDA
# 121  Europe & Central Asia          High income  Not classified
# 132    East Asia & Pacific  Upper middle income            IBRD
# 126             South Asia  Lower middle income            IBRD
# 141             South Asia  Lower middle income           Blend

# %%
fig = px.choropleth(df5, 
                    locations='Country Name',
                    locationmode="country names", 
                    color='value',
                    template="plotly_dark",
                    title = "2016 School Enrollments:"
                    )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="c2947b3f-864d-4270-9837-67d3cf2b4e86" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c2947b3f-864d-4270-9837-67d3cf2b4e86")) {                    Plotly.newPlot(                        "c2947b3f-864d-4270-9837-67d3cf2b4e86",                        [{"coloraxis":"coloraxis","geo":"geo","hovertemplate":"Country Name=%{location}<br>value=%{z}<extra></extra>","locationmode":"country names","locations":["Afghanistan","Afghanistan","Afghanistan","Australia","Australia","Australia","Australia","Australia","Bangladesh","Bangladesh","Bangladesh","China","China","China","China","China","Germany","Germany","Germany","Germany","India","India","India","India","Malaysia","Malaysia","Malaysia","Malaysia","Malaysia","Nepal","Nepal","Nepal","Nepal","Pakistan","Pakistan","Pakistan","Pakistan","United States","United States","United States","United States"],"name":"","z":[0.6456699967,0.6416900158000001,0.6360200047,0.9251700044,0.9375399947,0.9688500166,0.9640700221,0.9792900085,1.1166399717,1.1159100533,1.1458799839,1.0101399422,1.0132199526,1.0143100023,1.0152900219,1.0128699541,0.9637299776,0.9576500058,0.9609900117,0.9653699994,1.0951900482,1.0840200186,1.0201699734,1.0073800087,1.0388200283,1.0345400572,1.0465199947,1.0403800011,1.0395100117,1.056910038,1.0467799902,1.046489954,1.0122699738,0.8395100236,0.845960021,0.8488900065,0.8774799705,0.9962599874,0.993629992,0.9947000146,0.9949100018],"type":"choropleth"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888 ...

# %%
fig = px.line(
    df5, 
    x="Year", 
    labels={"value":"School Enrolment Rate %"},
    y="value",
    color="Country Name",
    title="School enrollment, primary and secondary (gross), gender parity index (GPI)."
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="024bbd6c-c65a-489d-b4c7-471a1c9f25ea" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("024bbd6c-c65a-489d-b4c7-471a1c9f25ea")) {                    Plotly.newPlot(                        "024bbd6c-c65a-489d-b4c7-471a1c9f25ea",                        [{"hovertemplate":"Country Name=Afghanistan<br>Year=%{x}<br>School Enrolment Rate %=%{y}<extra></extra>","legendgroup":"Afghanistan","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Afghanistan","orientation":"v","showlegend":true,"x":[2016,2017,2018],"xaxis":"x","y":[0.6456699967,0.6416900158000001,0.6360200047],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country Name=Australia<br>Year=%{x}<br>School Enrolment Rate %=%{y}<extra></extra>","legendgroup":"Australia","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Australia","orientation":"v","showlegend":true,"x":[2016,2017,2018,2019,2020],"xaxis":"x","y":[0.9251700044,0.9375399947,0.9688500166,0.9640700221,0.9792900085],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country Name=Bangladesh<br>Year=%{x}<br>School Enrolment Rate %=%{y}<extra></extra>","legendgroup":"Bangladesh","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Bangladesh","orientation":"v","showlegend":true,"x":[2017,2018,2020],"xaxis":"x","y":[1.1166399717,1.1159100533,1.1458799839],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country Name=China<br>Year=%{x}<br>School Enrolment Rate %=%{y}<extra></extra>","legendgroup":"China","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"China","orientation":"v","showlegend":true,"x":[2016,2017,2018,2019,2020],"xaxis":"x","y":[1.0101399422,1.0132199526,1.0143100023,1.0152900219,1.0128699541],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country Name=Germany<br>Year=%{x}<br>School Enrolment Rate %=%{y}<extra></extra>","legendgroup":"Germany","line":{"color":"#FFA15A","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Germany","orientation":"v","showlegend":true,"x":[2016,2017,2018,2019],"xaxis":"x","y":[0.9637299776,0.9576500058,0.9609900117,0.9653699994],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country Name=India<br>Year=%{x}<br>School Enrolment Rate %=%{y}<extra></extra>","legendgroup":"India","line":{"color":"#19d3f3","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"India","orientation":"v","showlegend":true,"x":[2016,2017,2019,2020],"xaxis":"x","y":[1.0951900482,1.0840200186,1.0201699734,1.0073800087],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country Name=Malaysia<br>Year=%{x}<br>School Enrolment Rate %=%{y}<extra></extra>","legendgroup":"Malaysia","line":{"color":"#FF6692","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Malaysia","orientation":"v","showlegend":true,"x":[2016,2017,2018,2019,2020],"xaxis":"x","y":[1.0388200283,1.0345400572,1.0465199947,1.0403800011,1.0395100117],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country Name=Nepal<br>Year=%{x}<br>School Enrolment Rate %=%{y}<extra></extra>","legendgroup":"Nepal","line":{"color":"#B6E880","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Nepal","orientation":"v","showlegend":true,"x":[2016,2017,2019,2020],"xaxis":"x","y":[1.056910038,1.0467799902,1.046489954,1.0122699738],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country Name=Pakistan<br>Year=%{x}<br>School Enrolment Rate %=%{y}<extra></extra>","legendgroup":"Pakistan","line":{"color":"#FF97FF","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Pakistan","orientation":"v","showlegend":true,"x":[2016,2017,2018,2019],"xaxis":"x","y" ...

# %% [markdown]
# * On whole , We have a huge enrollment into school in both Bangladesh and India but if we look into the Time series data, we can noticed that eventually from ear 2016 to 2021 Bangladesh has gradually increased its number, whereas we can see decline in the enrollments of India. Afghanistan stood last in enrollments. Rest of all the countries has its consistency among all the years, and they have a constant enrollments.

# %% [markdown]
# **Employment to population ratio:**

# %%
df6 = df.query("Year == 2016").query("indicator == 'SL.EMP.1524.SP.MA.ZS'")
df7 = df.query("Year == 2016").query("indicator == 'SL.EMP.1524.SP.FE.ZS'")

# %%
df6.sample(5)
# Out:
#      Unnamed: 0  Year      value             indicator Country Code  \
# 242         242  2016  43.445999  SL.EMP.1524.SP.MA.ZS          MYS
# 230         230  2016  46.946999  SL.EMP.1524.SP.MA.ZS          DEU
# 248         248  2016  68.164001  SL.EMP.1524.SP.MA.ZS          NPL
# 260         260  2016  45.549000  SL.EMP.1524.SP.MA.ZS          USA
# 206         206  2016  49.255001  SL.EMP.1524.SP.MA.ZS          AFG
#
#       Country Name                 Region         Income Group    Lending Type
# 242       Malaysia    East Asia & Pacific  Upper middle income            IBRD
# 230        Germany  Europe & Central Asia          High income  Not classified
# 248          Nepal             South Asia  Lower middle income             IDA
# 260  United States          North America          High income  Not classified
# 206    Afghanistan             South Asia           Low income             IDA

# %%
fig = px.bar(
    df6, 
    x="Country Name", 
    y="value", 
    title="Employment to population ratio, ages 15-24, male (%) (modeled ILO estimate)", 
    labels={"value":"2016 Male Details", "Country Name":""},
    color="Country Name", 
)


fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="d8a7c860-20ae-4211-88ad-e8d58b612020" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d8a7c860-20ae-4211-88ad-e8d58b612020")) {                    Plotly.newPlot(                        "d8a7c860-20ae-4211-88ad-e8d58b612020",                        [{"alignmentgroup":"True","hovertemplate":"=%{x}<br>2016 Male Details=%{y}<extra></extra>","legendgroup":"Afghanistan","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Afghanistan","offsetgroup":"Afghanistan","orientation":"v","showlegend":true,"textposition":"auto","x":["Afghanistan"],"xaxis":"x","y":[49.2550010681],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"=%{x}<br>2016 Male Details=%{y}<extra></extra>","legendgroup":"Australia","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Australia","offsetgroup":"Australia","orientation":"v","showlegend":true,"textposition":"auto","x":["Australia"],"xaxis":"x","y":[57.9029998779],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"=%{x}<br>2016 Male Details=%{y}<extra></extra>","legendgroup":"Bangladesh","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Bangladesh","offsetgroup":"Bangladesh","orientation":"v","showlegend":true,"textposition":"auto","x":["Bangladesh"],"xaxis":"x","y":[47.3979988098],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"=%{x}<br>2016 Male Details=%{y}<extra></extra>","legendgroup":"China","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"China","offsetgroup":"China","orientation":"v","showlegend":true,"textposition":"auto","x":["China"],"xaxis":"x","y":[49.0340003967],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"=%{x}<br>2016 Male Details=%{y}<extra></extra>","legendgroup":"Germany","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Germany","offsetgroup":"Germany","orientation":"v","showlegend":true,"textposition":"auto","x":["Germany"],"xaxis":"x","y":[46.9469985962],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"=%{x}<br>2016 Male Details=%{y}<extra></extra>","legendgroup":"India","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"India","offsetgroup":"India","orientation":"v","showlegend":true,"textposition":"auto","x":["India"],"xaxis":"x","y":[33.9239997864],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"=%{x}<br>2016 Male Details=%{y}<extra></extra>","legendgroup":"Malaysia","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Malaysia","offsetgroup":"Malaysia","orientation":"v","showlegend":true,"textposition":"auto","x":["Malaysia"],"xaxis":"x","y":[43.4459991455],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"=%{x}<br>2016 Male Details=%{y}<extra></extra>","legendgroup":"Nepal","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Nepal","offsetgroup":"Nepal","orientation":"v","showlegend":true,"textposition":"auto","x":["Nepal"],"xaxis":"x","y":[68.1640014648],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"=%{x}<br>2016 Male Details=%{y}<extra></extra>","legendgroup":"Pakistan","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"Pakistan","offsetgroup":"Pakistan","orientation":"v","showlegend":true,"textposition":"auto","x":["Pakistan"],"xaxis":"x","y":[55.0900001526],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"=%{x}<br>2016 Male Details=%{y}<extra></extra>","legendgroup":"United States","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"United States","offsetgroup":"United States","orientation":"v","showlegend":true,"textposition":"auto","x":["United States"],"xaxis":"x","y":[45.5489997864],"yaxis":"y","type":"bar"}],                   ...

# %%
df7.sample(5)
# Out:
#     Unnamed: 0  Year      value             indicator Country Code  \
# 57          57  2016  19.972000  SL.EMP.1524.SP.FE.ZS          BGD
# 51          51  2016  58.799000  SL.EMP.1524.SP.FE.ZS          AUS
# 63          63  2016  43.632999  SL.EMP.1524.SP.FE.ZS          CHN
# 75          75  2016   8.797000  SL.EMP.1524.SP.FE.ZS          IND
# 69          69  2016  44.508999  SL.EMP.1524.SP.FE.ZS          DEU
#
#    Country Name                 Region         Income Group    Lending Type
# 57   Bangladesh             South Asia  Lower middle income             IDA
# 51    Australia    East Asia & Pacific          High income  Not classified
# 63        China    East Asia & Pacific  Upper middle income            IBRD
# 75        India             South Asia  Lower middle income            IBRD
# 69      Germany  Europe & Central Asia          High income  Not classified

# %%
fig = px.bar(
    df7, 
    x="Country Name", 
    y="value", 
    title="Employment to population ratio, ages 15-24, female (%) (modeled ILO estimate)", 
    labels={"value":"2016 Female", "Country Name":""},
    color="Country Name", 
)


fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="e0fbe548-8eaa-4bc9-9cb9-6e11f65c3bdb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e0fbe548-8eaa-4bc9-9cb9-6e11f65c3bdb")) {                    Plotly.newPlot(                        "e0fbe548-8eaa-4bc9-9cb9-6e11f65c3bdb",                        [{"alignmentgroup":"True","hovertemplate":"=%{x}<br>2016 Female=%{y}<extra></extra>","legendgroup":"Afghanistan","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Afghanistan","offsetgroup":"Afghanistan","orientation":"v","showlegend":true,"textposition":"auto","x":["Afghanistan"],"xaxis":"x","y":[14.5719995499],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"=%{x}<br>2016 Female=%{y}<extra></extra>","legendgroup":"Australia","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Australia","offsetgroup":"Australia","orientation":"v","showlegend":true,"textposition":"auto","x":["Australia"],"xaxis":"x","y":[58.7989997864],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"=%{x}<br>2016 Female=%{y}<extra></extra>","legendgroup":"Bangladesh","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Bangladesh","offsetgroup":"Bangladesh","orientation":"v","showlegend":true,"textposition":"auto","x":["Bangladesh"],"xaxis":"x","y":[19.9720001221],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"=%{x}<br>2016 Female=%{y}<extra></extra>","legendgroup":"China","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"China","offsetgroup":"China","orientation":"v","showlegend":true,"textposition":"auto","x":["China"],"xaxis":"x","y":[43.6329994202],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"=%{x}<br>2016 Female=%{y}<extra></extra>","legendgroup":"Germany","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Germany","offsetgroup":"Germany","orientation":"v","showlegend":true,"textposition":"auto","x":["Germany"],"xaxis":"x","y":[44.5089988708],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"=%{x}<br>2016 Female=%{y}<extra></extra>","legendgroup":"India","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"India","offsetgroup":"India","orientation":"v","showlegend":true,"textposition":"auto","x":["India"],"xaxis":"x","y":[8.7969999313],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"=%{x}<br>2016 Female=%{y}<extra></extra>","legendgroup":"Malaysia","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Malaysia","offsetgroup":"Malaysia","orientation":"v","showlegend":true,"textposition":"auto","x":["Malaysia"],"xaxis":"x","y":[30.4619998932],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"=%{x}<br>2016 Female=%{y}<extra></extra>","legendgroup":"Nepal","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Nepal","offsetgroup":"Nepal","orientation":"v","showlegend":true,"textposition":"auto","x":["Nepal"],"xaxis":"x","y":[73.8740005493],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"=%{x}<br>2016 Female=%{y}<extra></extra>","legendgroup":"Pakistan","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"Pakistan","offsetgroup":"Pakistan","orientation":"v","showlegend":true,"textposition":"auto","x":["Pakistan"],"xaxis":"x","y":[17.7730007172],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"=%{x}<br>2016 Female=%{y}<extra></extra>","legendgroup":"United States","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"United States","offsetgroup":"United States","orientation":"v","showlegend":true,"textposition":"auto","x":["United States"],"xaxis":"x","y":[44.3650016785],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5 ...

# %% [markdown]
# * When we look into the employment to population ratio, we can see Nepal at top position followed by Australia and Pakistan. Indian stood at last.

# %% [markdown]
# ## Conclusion:
#
# - I have opted for these specific countries as they margin the line of connection between the variables. Each country has a specific highest or lowest unemployment rate, literacy rate and has a appropriate time series with respect to given topics. The literacy rate of youth is highest in Malaysia followed by Bangladesh.
# - The highest percentage of unemployment is taken by Afganisthan and the least is taken by Nepal. Afganisthan unemployment rate conquers 1/4th of the entire chart. We could conclude that Afganisthan is comparitively placed less when it comes to eduction, literacy rate leading to a higher percentage of unemployment rate.
# - Sometimes, data can be better understood when presented by a graph than by a table because the graph can reveal a trend or comparison and could represent thousands of words.
# - Graphs are effective visual tools because they present information quickly and easily. In the world of statistics, graphs display the relationship between variables or show the value spread of a given variable or phenomenon.
