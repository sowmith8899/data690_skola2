# %% [markdown]
# <a href="https://colab.research.google.com/github/sowmith8899/data690_skola2/blob/main/assignment_04/assignment_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Loading CSV File

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-b7c5e653-42e5-4a09-9edb-3054990d5bc5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b7c5e653-42e5-4a09-9edb-3054990d5bc5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

df = pd.read_csv("MERGED2017_18_PP.csv")
print(df)
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (1729) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#         UNITID    OPEID  OPEID6  \
# 0       100654   100200    1002
# 1       100663   105200    1052
# 2       100690  2503400   25034
# 3       100706   105500    1055
# 4       100724   100500    1005
# ...        ...      ...     ...
# 7107  48312404   108163    1081
# 7108  48387801  4223701   42237
# 7109  48400201  4228101   42281
# 7110  48778201  4221501   42215
# 7111  49005401  4182601   41826
#
#                                                  INSTNM             CITY  \
# 0                              Alabama A & M University           Normal
# 1                   University of Alabama at Birmingham       Birmingham
# 2                                    Amridge University       Montgomery
# ...

# %% [markdown]
# ###Exploring Data Frame

# %%
display(df)
# Out:
#         UNITID    OPEID  OPEID6  \
# 0       100654   100200    1002
# 1       100663   105200    1052
# 2       100690  2503400   25034
# 3       100706   105500    1055
# 4       100724   100500    1005
# ...        ...      ...     ...
# 7107  48312404   108163    1081
# 7108  48387801  4223701   42237
# 7109  48400201  4228101   42281
# 7110  48778201  4221501   42215
# 7111  49005401  4182601   41826
#
#                                                  INSTNM             CITY  \
# 0                              Alabama A & M University           Normal
# 1                   University of Alabama at Birmingham       Birmingham
# 2                                    Amridge University       Montgomery
# 3                   University of Alabama in Huntsville       Huntsville
# 4                              Alabama State University       Montgomery
# ...                                                 ...              ...
# ...

# %%
rows=len(df.axes[0])
cols=len(df.axes[1])
print("Number of rows are",rows)
print("Number of columns are",cols)
# Out:
# Number of rows are 7112
# Number of columns are 1986

# %%
df.head(5)
# Out:
#    UNITID    OPEID  OPEID6                               INSTNM        CITY  \
# 0  100654   100200    1002             Alabama A & M University      Normal
# 1  100663   105200    1052  University of Alabama at Birmingham  Birmingham
# 2  100690  2503400   25034                   Amridge University  Montgomery
# 3  100706   105500    1055  University of Alabama in Huntsville  Huntsville
# 4  100724   100500    1005             Alabama State University  Montgomery
#
#   STABBR         ZIP  ACCREDAGENCY  INSTURL  NPCURL  ...  \
# 0     AL       35762           NaN      NaN     NaN  ...
# 1     AL  35294-0110           NaN      NaN     NaN  ...
# 2     AL  36117-3553           NaN      NaN     NaN  ...
# 3     AL       35899           NaN      NaN     NaN  ...
# 4     AL  36104-0271           NaN      NaN     NaN  ...
#
#    OMENRUP_PARTTIME_POOLED_SUPP  FTFTPCTPELL  FTFTPCTFLOAN   UG12MN   G12MN  \
# 0                           NaN       0.7106        0.7418   5207.0  1185.0
# ...

# %%
df.tail(5)
# Out:
#         UNITID    OPEID  OPEID6  \
# 7107  48312404   108163    1081
# 7108  48387801  4223701   42237
# 7109  48400201  4228101   42281
# 7110  48778201  4221501   42215
# 7111  49005401  4182601   41826
#
#                                                  INSTNM             CITY  \
# 7107                   Arizona State University at Yuma             Yuma
# 7108  Bay Area Medical Academy - San Jose Satellite ...         San Jose
# 7109           High Desert Medical College - Bakerfield      Bakersfield
# 7110                                       BCI - Malden           Malden
# 7111               HCI College - Fort Lauderdale Campus  Fort Lauderdale
#
#      STABBR        ZIP  ACCREDAGENCY  INSTURL  NPCURL  ...  \
# 7107     AZ  853656900           NaN      NaN     NaN  ...
# 7108     CA      95113           NaN      NaN     NaN  ...
# 7109     CA      93301           NaN      NaN     NaN  ...
# 7110     MA  021480000           NaN      NaN     NaN  ...
# ...

# %%
df.sample(5)
# Out:
#       UNITID    OPEID  OPEID6  \
# 4662  428125  3125300   31253
# 14    101143   101500    1015
# 5224  448275  4028300   40283
# 4975  442806  3709300   37093
# 5045  444316  3763400   37634
#
#                                                  INSTNM        CITY STABBR  \
# 4662  John Wesley International Barber and Beauty Co...  Long Beach     CA
# 14                   Enterprise State Community College  Enterprise     AL
# 5224                   Mountain State School of Massage  Charleston     WV
# 4975         Edward Via College of Osteopathic Medicine  Blacksburg     VA
# 5045                                Bold Beauty Academy    Billings     MT
#
#              ZIP  ACCREDAGENCY  INSTURL  NPCURL  ...  \
# 4662       90813           NaN      NaN     NaN  ...
# 14    36330-1300           NaN      NaN     NaN  ...
# 5224       25304           NaN      NaN     NaN  ...
# 4975       24060           NaN      NaN     NaN  ...
# 5045       59101           NaN      NaN     NaN  ...
#
# ...

# %% [markdown]
# ###Creating a smaller data frame with the following 9 variables and it's defination
#
# - **UNITID** -- Unit ID for institution
# - **INSTNM** -- Institution name
# - **CITY** -- City
# - **STABBR** -- State postcode
# - **ZIP** -- ZIP code
# - **ADM_RATE** -- Admission rate
# - **UGDS** -- Enrollment of undergraduate certificate/degree-seeking students
# - **TUITIONFEE_IN** -- In-state tuition and fees
# - **MN_EARN_WNE_P10** -- Mean earnings of students working and not enrolled 10 years after entry
#
# ref : https://collegescorecard.ed.gov/assets/CollegeScorecardDataDictionary.xlsx (*Institution_Data_Dictionary* tab in workbook)

# %%
small_df = df.filter(["UNITID","INSTNM","CITY","STABBR","ZIP","ADM_RATE","UGDS","TUITIONFEE_IN","MN_EARN_WNE_P10" ])
display(small_df)
# Out:
#         UNITID                                             INSTNM  \
# 0       100654                           Alabama A & M University
# 1       100663                University of Alabama at Birmingham
# 2       100690                                 Amridge University
# 3       100706                University of Alabama in Huntsville
# 4       100724                           Alabama State University
# ...        ...                                                ...
# 7107  48312404                   Arizona State University at Yuma
# 7108  48387801  Bay Area Medical Academy - San Jose Satellite ...
# 7109  48400201           High Desert Medical College - Bakerfield
# 7110  48778201                                       BCI - Malden
# 7111  49005401               HCI College - Fort Lauderdale Campus
#
#                  CITY STABBR         ZIP  ADM_RATE     UGDS  TUITIONFEE_IN  \
# 0              Normal     AL       35762    0.9027   4824.0         9857.0
# ...

# %% [markdown]
# ### Exploring the small dataframe

# %%
small_df.head(10)
# Out:
#    UNITID                               INSTNM            CITY STABBR  \
# 0  100654             Alabama A & M University          Normal     AL
# 1  100663  University of Alabama at Birmingham      Birmingham     AL
# 2  100690                   Amridge University      Montgomery     AL
# 3  100706  University of Alabama in Huntsville      Huntsville     AL
# 4  100724             Alabama State University      Montgomery     AL
# 5  100751            The University of Alabama      Tuscaloosa     AL
# 6  100760    Central Alabama Community College  Alexander City     AL
# 7  100812              Athens State University          Athens     AL
# 8  100830      Auburn University at Montgomery      Montgomery     AL
# 9  100858                    Auburn University          Auburn     AL
#
#           ZIP  ADM_RATE     UGDS  TUITIONFEE_IN  MN_EARN_WNE_P10
# 0       35762    0.9027   4824.0         9857.0              NaN
# 1  35294-0110    0.9181  12866.0         8328.0              NaN
# ...

# %%
small_df.tail(10)
# Out:
#         UNITID                                             INSTNM  \
# 7102  48154401  National Personal Training Institute of Cleveland
# 7103  48305401             Barber School of Pittsburgh - Ambridge
# 7104  48312401                 Arizona State University at Tucson
# 7105  48312402  Arizona State University - ASU Colleges at Lak...
# 7106  48312403        Arizona State University at The Gila Valley
# 7107  48312404                   Arizona State University at Yuma
# 7108  48387801  Bay Area Medical Academy - San Jose Satellite ...
# 7109  48400201           High Desert Medical College - Bakerfield
# 7110  48778201                                       BCI - Malden
# 7111  49005401               HCI College - Fort Lauderdale Campus
#
#                   CITY STABBR        ZIP  ADM_RATE  UGDS  TUITIONFEE_IN  \
# 7102  Highland Heights     OH      44143       NaN   NaN            NaN
# 7103          Ambridge     PA  150030000       NaN   NaN            NaN
# ...

# %%
small_df.sample(10)
# Out:
#         UNITID                                         INSTNM  \
# 2507    198561                        Gardner-Webb University
# 3615    230959                             Middlebury College
# 3131    215637   The Restaurant School at Walnut Hill College
# 6596    490142          World Class Academy of Beauty Careers
# 727     135610       Trinity International University-Florida
# 3028    213303                               Keystone College
# 3623    231095                               Sterling College
# 3606    230816                             Bennington College
# 6948  24297205  National University College - Mayaguez Campus
# 2818    206862                   Southern Nazarene University
#
#                    CITY STABBR         ZIP  ADM_RATE    UGDS  TUITIONFEE_IN  \
# 2507    Boiling Springs     NC  28017-0997    0.5270  2210.0        30700.0
# 3615         Middlebury     VT       05753    0.1710  2532.0        52496.0
# ...

# %% [markdown]
# ### Selecting UMBC,Maryland College Park,Loyola College Maryland,Johns Hopskins and Calculating the min, max, and average in-state tution fees of them

# %%
sd1 = small_df.loc[small_df["INSTNM"].str.contains("University of Maryland-Baltimore County")]
sd1
# Out:
#       UNITID                                   INSTNM       CITY STABBR  \
# 1478  163268  University of Maryland-Baltimore County  Baltimore     MD
#
#         ZIP  ADM_RATE     UGDS  TUITIONFEE_IN  MN_EARN_WNE_P10
# 1478  21250    0.6021  11130.0        11518.0              NaN

# %%
sd2 = small_df.loc[small_df["INSTNM"].str.contains("University of Maryland-College Park")]
sd2
# Out:
#       UNITID                               INSTNM          CITY STABBR    ZIP  \
# 1479  163286  University of Maryland-College Park  College Park     MD  20742
#
#       ADM_RATE     UGDS  TUITIONFEE_IN  MN_EARN_WNE_P10
# 1479     0.445  29273.0        10399.0              NaN

# %%
sd3 = small_df.loc[small_df["INSTNM"].str.contains("Loyola University Maryland")]
sd3
# Out:
#       UNITID                      INSTNM       CITY STABBR         ZIP  \
# 1475  163046  Loyola University Maryland  Baltimore     MD  21210-2699
#
#       ADM_RATE    UGDS  TUITIONFEE_IN  MN_EARN_WNE_P10
# 1475    0.7528  3903.0        47560.0              NaN

# %%
sd4 = small_df.loc[small_df["INSTNM"].str.contains("Johns Hopkins University")]
sd4
# Out:
#       UNITID                    INSTNM       CITY STABBR         ZIP  \
# 1473  162928  Johns Hopkins University  Baltimore     MD  21218-2688
#
#       ADM_RATE    UGDS  TUITIONFEE_IN  MN_EARN_WNE_P10
# 1473    0.1254  5663.0        52170.0              NaN

# %%
df_4 = pd.concat([sd1,sd2,sd3,sd4])
df_4
# Out:
#       UNITID                                   INSTNM          CITY STABBR  \
# 1478  163268  University of Maryland-Baltimore County     Baltimore     MD
# 1479  163286      University of Maryland-College Park  College Park     MD
# 1475  163046               Loyola University Maryland     Baltimore     MD
# 1473  162928                 Johns Hopkins University     Baltimore     MD
#
#              ZIP  ADM_RATE     UGDS  TUITIONFEE_IN  MN_EARN_WNE_P10
# 1478       21250    0.6021  11130.0        11518.0              NaN
# 1479       20742    0.4450  29273.0        10399.0              NaN
# 1475  21210-2699    0.7528   3903.0        47560.0              NaN
# 1473  21218-2688    0.1254   5663.0        52170.0              NaN

# %%
mi=df_4["TUITIONFEE_IN"].min()
mx=df_4["TUITIONFEE_IN"].max()
avg=df_4["TUITIONFEE_IN"].mean()

print("minimun in-state tution of the above four institutions is ",mi)
print("maximum in-state tution of the above four institutions is ",mx)
print("average in-state tution of the above four institutions is",avg)
# Out:
# minimun in-state tution of the above four institutions is  10399.0
# maximum in-state tution of the above four institutions is  52170.0
# average in-state tution of the above four institutions is 30411.75

# %% [markdown]
# ### Filtering the smaller dataset further to only keep colleges from Maryland, Virgina, Washington DC, Delaware, and Pennsylvinia. Save the filtered dataset to a new file named "*Five_States_Colleges.csv*"

# %%
new_df = small_df.loc[small_df["STABBR"].isin(["MD","VA","DC","DE","PA"])]
new_df
# Out:
#         UNITID                                             INSTNM  \
# 634     130837  Margaret H Rollins School of Nursing at Beebe ...
# 635     130873                          Dawn Career Institute LLC
# 636     130907         Delaware Technical Community College-Terry
# 637     130934                          Delaware State University
# 638     130943                             University of Delaware
# ...        ...                                                ...
# 7063  45794301   Somerset County Technology Center - Bedford Site
# 7084  47503303      Relay Graduate School of Education - Delaware
# 7089  47503308  Relay Graduate School of Education - Philadelp...
# 7094  47503313  Relay Graduate School of Education - Washingto...
# 7103  48305401             Barber School of Pittsburgh - Ambridge
#
#               CITY STABBR        ZIP  ADM_RATE     UGDS  TUITIONFEE_IN  \
# 634          Lewes     DE      19958       NaN     59.0            NaN
# ...

# %%
new_df.to_csv("Five_states_colleges.csv")
files.download("Five_states_colleges.csv")

# %%
# %ll
# Out:
# total 132116
# -rw-r--r-- 1 root    56610 Sep 24 20:38  Five_states_colleges.csv
# -rw-r--r-- 1 root 67608877 Sep 24 19:38 'MERGED2017_18_PP (1).csv'
# -rw-r--r-- 1 root 67608877 Sep 24 18:25  MERGED2017_18_PP.csv
# drwxr-xr-x 1 root     4096 Sep 22 13:42  sample_data/
